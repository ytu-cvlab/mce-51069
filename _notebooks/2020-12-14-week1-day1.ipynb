# %% [markdown]
# # Week 1, Day 1 (Introduction to the course)
# > TODO
#
# - toc: true
# - badges: false
# - comments: true
# - categories: [image_processing, overview]

# %% [markdown]
# # What is Anaconda and Jupyter Notebook

# %% [markdown]
# # Install on Window

# %%
#hide
from IPython.display import YouTubeVideo
YouTubeVideo('-d4aMzxo7P0', width=800, height=450)

# %% [markdown]
# # Install on Mac

# %% [markdown]
# # How to use Jupyter Notebook

# %%
#hide
from IPython.display import YouTubeVideo
YouTubeVideo('yQuN-mobErE', width=800, height=450)
